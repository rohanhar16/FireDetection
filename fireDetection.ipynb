# %% [markdown]
# ## Cloning the YOLO-V5 FILES FROM THE GITHUB REPOSITORY

# %%
    # !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14992, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# ...

# %% [markdown]
# ## Changing the directory

# %%
# %cd yolov5
# Out:
# /home/christ-infotech-007/Rohan/FireDetection/yolov5

# %% [markdown]
# ## Installing the dependencies

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 kB 1.2 MB/s eta 0:00:001m884.0 kB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 15.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached numpy-1.24.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 343.5 kB/s eta 0:00:00m eta 0:00:010:00:05
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 546.0 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 542.3 kB/s eta 0:00:000:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 268.4 kB/s eta 0:00:00m eta 0:00:010:00:04
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 755.7 kB/s eta 0:00:00m eta 0:00:010:00:22
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 1.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %% [markdown]
# ## Divide the dataset into train and test sets

# %%
import os
from random import choice
import shutil

#arrays to store file names
imgs =[]
xmls =[]

#setup dir names
trainPath = '/home/christ-infotech-007/Rohan/FireDetection/dataset/images/train'
valPath = '/home/christ-infotech-007/Rohan/FireDetection/dataset/images/val'
crsPath = '/home/christ-infotech-007/Rohan/FireDetection/dataset/data' #dir where images and annotations stored

#setup ratio (val ratio = rest of the files in origin dir after splitting into train and test)
train_ratio = 0.8
val_ratio = 0.2


#total count of imgs
totalImgCount = len(os.listdir(crsPath))/2

#soring files to corresponding arrays
for (dirname, dirs, files) in os.walk(crsPath):
    for filename in files:
        if filename.endswith('.txt'):
            xmls.append(filename)
        else:
            imgs.append(filename)


#counting range for cycles
countForTrain = int(len(imgs)*train_ratio)
countForVal= int(len(imgs)*val_ratio)
print("training images are : ",countForTrain)
print("validating images are : ",countForVal)
# Out:
# training images are :  157
# validating images are :  39

# %%
trainimagePath = '/home/christ-infotech-007/Rohan/FireDetection/dataset/images/train'
trainlabelPath = '/home/christ-infotech-007/Rohan/FireDetection/dataset/labels/train'
valimagePath = '/home/christ-infotech-007/Rohan/FireDetection/dataset/images/val'
vallabelPath = '/home/christ-infotech-007/Rohan/FireDetection/dataset/labels/val'
#cycle for train dir
for x in range(countForTrain):

    fileJpg = choice(imgs) # get name of random image from origin dir
    fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

    #move both files into train dir
    #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(trainimagePath, fileJpg))
    #shutil.move(os.path.join(crsPath, fileXml), os.path.join(trainlabelPath, fileXml))
    shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(trainimagePath, fileJpg))
    shutil.copy(os.path.join(crsPath, fileXml), os.path.join(trainlabelPath, fileXml))


    #remove files from arrays
    imgs.remove(fileJpg)
    xmls.remove(fileXml)



#cycle for test dir
for x in range(countForVal):

    fileJpg = choice(imgs) # get name of random image from origin dir
    fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

    #move both files into train dir
    #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
    #shutil.move(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))
    shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
    shutil.copy(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))

    #remove files from arrays
    imgs.remove(fileJpg)
    xmls.remove(fileXml)

#rest of files will be validation files, so rename origin dir to val dir
#os.rename(crsPath, valPath)
shutil.move(crsPath, valPath)
# Out:
# '/home/christ-infotech-007/Rohan/FireDetection/dataset/images/test/data'

# %% [markdown]
# ## Training yolov5 with cuntom fire dataset, Batch: 7, number of epochs: 10, weights: yolov5s.pt

# %%
# !python  train.py --img 157 --batch 3 --epochs 10 --data dataset.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=3, imgsz=157, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-70-g589edc7 Python-3.10.6 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1630, 3896MiB)
#
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# Launching TensorBoard...

# %% [markdown]
# ## Testing the model with real time data using web cam.
# ### Note: source 0 will help to open the web cam.

# %%
# !python detect.py --source 1 --weights /home/christ-infotech-007/Rohan/FireDetection/yolov5/runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['/home/christ-infotech-007/Rohan/FireDetection/yolov5/runs/train/exp2/weights/best.pt'], source=1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-70-g589edc7 Python-3.10.6 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1630, 3896MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# 1/1: 1...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 480x640 (no detections), 705.5ms
# 0: 480x640 (no detections), 21.0ms
# 0: 480x640 (no detections), 18.1ms
# 0: 480x640 (no detections), 20.1ms
# 0: 480x640 (no detections), 16.5ms
# 0: 480x640 (no detections), 23.5ms
# ...
